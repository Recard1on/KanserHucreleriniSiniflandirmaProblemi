# %% [markdown]
# ### Verimizi ve gerekli kütüphaneleri import ediyoruz.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings 
warnings.filterwarnings(action= 'ignore')

# %% [markdown]
# ### Verimizi import ediyoruz ve ilk 5 satırı görüntülüyoruz.

# %%
train_df = pd.read_csv("../Dataset/kanser.csv")
train_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Verimizin bilgilerini kontrol ettik.

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ### Verimizde bir tane hepsi boş değerlerden oluşan bir sutunu ve id kolonunu sildik.

# %%
train_df.drop(["Unnamed: 32","id"],axis=1,inplace=True)

# %% [markdown]
# ### verimizdeki sayıları ortalama min ve max değerleri görmek için describe fonksiyonun kullandık.

# %%
train_df.describe().T
# Out:
#                          count        mean         std         min  \
# radius_mean              569.0   14.127292    3.524049    6.981000
# texture_mean             569.0   19.289649    4.301036    9.710000
# perimeter_mean           569.0   91.969033   24.298981   43.790000
# area_mean                569.0  654.889104  351.914129  143.500000
# smoothness_mean          569.0    0.096360    0.014064    0.052630
# compactness_mean         569.0    0.104341    0.052813    0.019380
# concavity_mean           569.0    0.088799    0.079720    0.000000
# concave points_mean      569.0    0.048919    0.038803    0.000000
# symmetry_mean            569.0    0.181162    0.027414    0.106000
# fractal_dimension_mean   569.0    0.062798    0.007060    0.049960
# radius_se                569.0    0.405172    0.277313    0.111500
# texture_se               569.0    1.216853    0.551648    0.360200
# perimeter_se             569.0    2.866059    2.021855    0.757000
# ...

# %% [markdown]
# ### Kanser hücremizin verimizde kaç tane iyi kaç tane kötü var diye teşhislerimizin bir grafiğini çizdik.

# %%
sns.countplot(train_df["diagnosis"])
train_df["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ### Verimizdeki korelasyona bakmak istedik fakat çok fazla kolon olduğu için kafa karışıklığına sebep olacağı için belli bir eşik değeri belirleyip bir filtre atayıp değerleri kontrol ettik.

# %%
corr_data = train_df.corr()[train_df.corr()>0.8]

# %%
sns.heatmap(cor_data)
# Out:
# <AxesSubplot:>

# %%
train_df.corr()[train_df.corr()<0.4]
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                      NaN      0.323782             NaN        NaN
# texture_mean                0.323782           NaN        0.329533   0.321086
# perimeter_mean                   NaN      0.329533             NaN        NaN
# area_mean                        NaN      0.321086             NaN        NaN
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean                 NaN      0.236702             NaN        NaN
# concavity_mean                   NaN      0.302418             NaN        NaN
# concave points_mean              NaN      0.293464             NaN        NaN
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                        NaN      0.275869             NaN        NaN
# ...

# %% [markdown]
# ### texture_se, smoothness_se, fractal_dimension_mean, symmetry_se satırlarını silmek istedim çünkü korelasyonda çok az etkiliyorlar

# %%
train_df.drop(["fractal_dimension_mean","texture_se","smoothness_se","symmetry_se"],axis=1,inplace=True)
train_df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ### Teşhisin değerini 1(iyi huylu),0(kötü huylu) olarak değiştirdik.

# %%
train_df["diagnosis"] = [0 if i=="M" else 1 for i in train_df["diagnosis"]]

# %%
train_df.drop(["radius_worst","perimeter_worst","area_worst","concave points_worst"],axis=1,inplace=True)

# %%
train_df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  compactness_se  concavity_se  concave points_se  \
# ...

# %% [markdown]
# ### outlier veriler var mı diye bir formülasyon uyguladık kurduğumuz bu formülasyona göre outlier verileri görüntüledik ve sildik

# %%
for i in train_df.columns[1:]:
    mean = train_df[i].mean()
    st = train_df[i].std()
    ust_sinir = (2.5*st)+mean
    alt_sinir = mean - (2.5*st)
    train_df.drop(train_df[(train_df[i] >=ust_sinir) | (train_df[i] <= alt_sinir)].index, inplace=True)
    print(train_df[(train_df[i] >= ust_sinir) | (train_df[i] <=alt_sinir )])
# Out:
# Empty DataFrame
# Columns: [diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, radius_se, perimeter_se, area_se, compactness_se, concavity_se, concave points_se, fractal_dimension_se, texture_worst, smoothness_worst, compactness_worst, concavity_worst, symmetry_worst, fractal_dimension_worst]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, radius_se, perimeter_se, area_se, compactness_se, concavity_se, concave points_se, fractal_dimension_se, texture_worst, smoothness_worst, compactness_worst, concavity_worst, symmetry_worst, fractal_dimension_worst]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# ...

# %%
train_df
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 6            0       18.250         19.98          119.60     1040.0
# 10           0       16.020         23.24          102.70      797.8
# 13           0       15.850         23.95          103.70      782.7
# 16           0       14.680         20.13           94.74      684.5
# 19           1       13.540         14.36           87.46      566.3
# ..         ...          ...           ...             ...        ...
# 556          1       10.160         19.59           64.73      311.7
# 557          1        9.423         27.88           59.26      271.3
# 559          1       11.510         23.93           74.52      403.5
# 560          1       14.050         27.15           91.38      600.4
# 566          0       16.600         28.08          108.30      858.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# ### Modelimizi oluşturup eğitip test ettik

# %%
X = train_df.drop(["diagnosis"],axis=1)
Y = train_df["diagnosis"]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.25,random_state=81)
print("X_train",len(x_train))
print("X_test",len(x_test))
print("y_train",len(y_train))
print("y_test",len(y_test))
# Out:
# X_train 276
# X_test 92
# y_train 276
# y_test 92

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(x_train, y_train)
acc_log_train = round(logreg.score(x_train, y_train)*100,2) 
acc_log_test = round(logreg.score(x_test,y_test)*100,2)
print("Training Accuracy: % {}".format(acc_log_train))
print("Testing Accuracy: % {}".format(acc_log_test))
# Out:
# Training Accuracy: % 98.55
# Testing Accuracy: % 96.74
